# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/01.Ha\'/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.12 s
# after trim Max Duration: 16.128 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')
    
# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/02.Kha\'/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 18.08 s
# after trim Max Duration: 15.264 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/03.Shad/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 18.24 s
# after trim Max Duration: 17.066666666666666 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')
# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/04.Dhad/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.6 s
# after trim Max Duration: 16.512 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')
# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/05.Tha\'/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.28 s
# after trim Max Duration: 15.338666666666667 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/06.Dhza\'/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.12 s
# after trim Max Duration: 15.157333333333334 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/07.\'Ain/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.12 s
# after trim Max Duration: 15.136 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/08.Ghain/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.76 s
# after trim Max Duration: 15.946666666666667 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')
# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/09.Qaf/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 17.92 s
# after trim Max Duration: 16.938666666666666 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../Dataset/10.Ha^\'/"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 48000 Hz
# Lowest Sampling Rate: 48000 Hz
# Max Duration: 18.4 s
# after trim Max Duration: 17.173333333333332 s

# %% [markdown]
# INI UNTUK SAMPLE DATASET

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')

# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../sample_dataset/ha"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 44100 Hz
# Lowest Sampling Rate: 44100 Hz
# Max Duration: 0.65 s
# after trim Max Duration: 0.4295691609977324 s

# %%
import os
import librosa

def find_sampling_rate(folder_path):
    # Mendapatkan daftar file dalam folder
    files = [f for f in os.listdir(folder_path) if f.endswith('.wav')]

    # Inisialisasi nilai sampling rate tertinggi dan terendah
    highest_sampling_rate = float('-inf')
    lowest_sampling_rate = float('inf')
    max_duration = 0
    max_duration_after_trim = 0

    # Iterasi melalui setiap file
    for file in files:
        file_path = os.path.join(folder_path, file)
        try:
            # Membaca informasi file audio menggunakan librosa
            y, sr = librosa.load(file_path, sr=None)
            duration = librosa.get_duration(y=y, sr=sr)
            y_trim, _ = librosa.effects.trim(y, top_db=20)
            trim_duration = librosa.get_duration(y=y_trim, sr=sr)
            if (duration > max_duration):
                max_duration = duration

            if(trim_duration>max_duration_after_trim):
                max_duration_after_trim = trim_duration
            # Memeriksa dan memperbarui nilai sampling rate tertinggi dan terendah
            if sr > highest_sampling_rate:
                highest_sampling_rate = sr
            if sr < lowest_sampling_rate:
                lowest_sampling_rate = sr
        except Exception as e:
            print(f"Error processing file {file}: {e}")

    # Menampilkan hasil
    print(f"Highest Sampling Rate: {highest_sampling_rate} Hz")
    print(f"Lowest Sampling Rate: {lowest_sampling_rate} Hz")
    print(f'Max Duration: {max_duration} s')
    print(f'after trim Max Duration: {max_duration_after_trim} s')
# Ganti path_folder dengan path ke folder yang berisi file audio
path_folder = "../sample_dataset/qa"
find_sampling_rate(path_folder)
# Out:
# Highest Sampling Rate: 44100 Hz
# Lowest Sampling Rate: 44100 Hz
# Max Duration: 0.65 s
# after trim Max Duration: 0.4179591836734694 s
